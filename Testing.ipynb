# %%
# Start writing code here...
Hello
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-adbe592d5d9e> in <module>
#       1 # Start writing code here...
# ----> 2 Hello
#
# NameError: name 'Hello' is not defined
